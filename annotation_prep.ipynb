# %% [markdown]
# # Select trials based on shape identifiers

# %%
import os
from glob import glob
import random
import pandas as pd 
import numpy as np
import shutil

from utils.io import load_log_trials, add_video_path

# %%
# Setting
data_dir = r"/media/yiting/NewVolume/Data/Videos"
annotation_dir = r"/home/yiting/Documents/Data/Videos/Annotations"
session_name = "2025-12-07"
log_dir = os.path.join(data_dir, session_name, "trial_logs")
log_trials = sorted(glob(os.path.join(log_dir, "*.json")))
logs = load_log_trials(log_trials)
video_folder_paths = sorted(glob(os.path.join(data_dir, session_name, "cameras", "*")))
logs = add_video_path(video_folder_paths, logs)
# Select shape IDs
# selected_shape_ids = ["G345", "G617", "G877", "G355", "B251", "G345", "G255", "G235", "G812", "B603", "G869"]
shape_ids = logs["shape_id"]
unique_shape_ids = list(set(shape_ids))
random.seed(42)
# selected_shape_ids = random.sample(unique_shape_ids, 11)
# print("Selected shape IDs:", selected_shape_ids)

# %% [markdown]
# ## Copy selected videos to the annotation folder

# %%
for selected_shape_id in unique_shape_ids:
    shape_trials = []
    for idx, shape_id  in enumerate(shape_ids):
        if selected_shape_id in shape_id:
            shape_trials.append(idx)
    # Randomly select one trial from the shape_trials
    selected_trial_idx = random.choice(shape_trials)
    selected_video_folder = logs.iloc[selected_trial_idx]["video_folder_name"]
    video_folder_path = os.path.join(data_dir, session_name, "cameras", selected_video_folder)
    print(f"Shape ID: {selected_shape_id}, Trials: {shape_trials}, Selected Trial Index: {selected_trial_idx}, Video Folder Path: {video_folder_path}")
    # Copy the selected video folder to annotation directory
    os.makedirs(os.path.join(annotation_dir, session_name), exist_ok=True)
    shutil.copytree(video_folder_path, os.path.join(annotation_dir, session_name, selected_video_folder))
# Out:
# Shape ID: G226_0, Trials: [360, 361, 362, 363, 388, 393, 406, 407, 426, 430, 431], Selected Trial Index: 431, Video Folder Path: /media/yiting/NewVolume/Data/Videos/2025-12-07/cameras/2025-12-07_12-18-32_454057
# Shape ID: G699_0, Trials: [86, 87, 109, 122, 129, 130, 131, 132, 158, 159], Selected Trial Index: 87, Video Folder Path: /media/yiting/NewVolume/Data/Videos/2025-12-07/cameras/2025-12-07_10-06-24_778105
# Shape ID: G345_2, Trials: [88, 100, 108, 110, 111, 112, 143, 145, 152, 156, 167], Selected Trial Index: 88, Video Folder Path: /media/yiting/NewVolume/Data/Videos/2025-12-07/cameras/2025-12-07_10-06-36_589304
# Shape ID: G750_2, Trials: [444, 451, 458, 459, 460, 468, 475, 478, 479, 495], Selected Trial Index: 460, Video Folder Path: /media/yiting/NewVolume/Data/Videos/2025-12-07/cameras/2025-12-07_12-25-50_648903
# Shape ID: G358_0, Trials: [11, 12, 24, 25, 26, 27, 55, 62, 67, 79, 80], Selected Trial Index: 25, Video Folder Path: /media/yiting/NewVolume/Data/Videos/2025-12-07/cameras/2025-12-07_09-47-01_266789
# Shape ID: G846_2, Trials: [253, 254, 270, 276, 277, 281, 282, 288, 298, 299, 309, 310, 324, 334, 335, 337, 339, 340, 341, 342, 343, 344], Selected Trial Index: 288, Video Folder Path: /media/yiting/NewVolume/Data/Videos/2025-12-07/cameras/2025-12-07_11-07-52_015104
# Shape ID: G122_2, Trials: [346, 372, 373, 374, 391, 392, 405, 415, 416, 417], Selected Trial Index: 373, Video Folder Path: /media/yiting/NewVolume/Data/Videos/2025-12-07/cameras/2025-12-07_12-05-40_064840
# Shape ID: G224_0, Trials: [507, 512, 520, 526, 527, 528, 546, 547, 569, 583, 584], Selected Trial Index: 512, Video Folder Path: /media/yiting/NewVolume/Data/Videos/2025-12-07/cameras/2025-12-07_12-38-22_358706
# Shape ID: G202_0, Trials: [588, 590, 591, 592], Selected Trial Index: 588, Video Folder Path: /media/yiting/NewVolume/Data/Videos/2025-12-07/cameras/2025-12-07_13-34-54_552277
# Shape ID: G652_02, Trials: [593], Selected Trial Index: 593, Video Folder Path: /media/yiting/NewVolume/Data/Videos/2025-12-07/cameras/2025-12-07_13-35-49_394619
# Shape ID: G124_2, Trials: [2, 13, 30, 31, 42, 43, 44, 45, 65, 66], Selected Trial Index: 2, Video Folder Path: /media/yiting/NewVolume/Data/Videos/2025-12-07/cameras/2025-12-07_09
Video Folder Path: /media/yiting/NewVolume/Data/Videos/2025-12-07/cameras/2025-12-07_12-58-54_325768
# Shape ID: G204_2, Trials: [258, 259, 271, 272, 285, 293, 306, 308, 320, 321], Selected Trial Index: 285, Video Folder Path: /media/yiting/NewVolume/Data/Videos/2025-12-07/cameras/2025-12-07_11-07-12_519163
# Shape ID: B251_02, Trials: [439, 449, 450, 461, 462, 463, 472, 481, 482, 483], Selected Trial Index: 450, Video Folder Path: /media/yiting/NewVolume/Data/Videos/2025-12-07/cameras/2025-12-07_12-23-36_115627
# Shape ID: G140_2, Trials: [7, 8, 32, 35, 51, 52, 54, 59, 64, 78], Selected Trial Index: 35, Video Folder Path: /media/yiting/NewVolume/Data/Videos/2025-12-07/cameras/2025-12-07_09-49-12_721900
# Shape ID: G345_0, Trials: [89, 90, 107, 126, 133, 134, 135, 136, 137, 161, 162], Selected Trial Index: 134, Video Folder Path: /media/yiting/NewVolume/Data/Videos/2025-12-07/cameras/2025-12-07_10-16-18_000780
# Shape ID: G625_2, Trials: [347, 370, 371, 382, 383, 395, 397, 400, 401, 411, 412, 413], Selected Trial Index: 370, Video Folder Path: /media/yiting/NewVolume/Data/Videos/2025-12-07/cameras/2025-12-07_12-04-59_579868
# Shape ID: G224_2, Trials: [510, 518, 524, 525, 538, 539, 549, 560, 566, 567, 571, 578, 580, 581, 582], Selected Trial Index: 518, Video Folder Path: /media/yiting/NewVolume/Data/Videos/2025-12-07/cameras/2025-12-07_12-39-37_260015
# Shape ID: G204_0, Trials: [248, 249, 269, 278, 280, 290, 291, 292, 311, 318, 319], Selected Trial Index: 291, Video Folder Path: /media/yiting/NewVolume/Data/Videos/2025-12-07/cameras/2025-12-07_11-08-31_473320
# Shape ID: G075_2, Trials: [83, 105, 106, 123, 124, 125, 138, 139, 140, 160, 165, 166], Selected Trial Index: 105, Video Folder Path: /media/yiting/NewVolume/Data/Videos/2025-12-07/cameras/2025-12-07_10-10-07_027883
# Shape ID: G139_2, Trials: [170, 171, 172, 193, 194, 195, 196, 228, 243, 247], Selected Trial Index: 195, Video Folder Path: /media/yiting/NewVolume/Data/Videos/2025-12-07/cameras/2025-12-07_10-30-22_277071
# Shape ID: G846_0, Trials: [257, 261, 267, 268, 286, 287, 302, 312, 313, 327, 328, 329, 330, 331, 332, 333], Selected Trial Index: 329, Video Folder Path: /media/yiting/NewVolume/Data/Videos/2025-12-07/cameras/2025-12-07_11-19-17_485399
# Shape ID: G075_0, Trials: [91, 92, 93, 94, 117, 118, 119, 120, 121, 153, 164], Selected Trial Index: 153, Video Folder Path: /media/yiting/NewVolume/Data/Videos/2025-12-07/cameras/2025-12-07_10-20-22_212512
# Shape ID: G730_2, Trials: [0, 14, 28, 29, 49, 50, 53, 63, 73, 74], Selected Trial Index: 49, Video Folder Path: /media/yiting/NewVolume/Data/Videos/2025-12-07/cameras/2025-12-07_09-52-11_207469
# Shape ID: G750_0, Trials: [443, 445, 446, 447, 465, 466, 467, 484, 488, 492, 493], Selected Trial Index: 443, Video Folder Path: /media/yiting/NewVolume/Data/Videos/2025-12-07/cameras/2025-12-07_12-21-59_390964
# Shape ID: G121_2, Trials: [498, 499, 500, 501, 502, 503, 541, 542, 561, 573, 577, 585], Selected Trial Index: 585, Video Folder Path: /media/yiting/NewVolume/Data/Videos/2025-12-07/cameras/2025-12-07_13-25-05_878284
# Shape ID: G702_02, Trials: [260, 262, 263, 279, 283, 289, 294, 295, 296, 297, 322, 323], Selected Trial Index: 295, Video Folder Path: /media/yiting/NewVolume/Data/Videos/2025-12-07/cameras/2025-12-07_11-09-22_461330
# Shape ID: G210_0, Trials: [95, 96, 97, 98, 99, 141, 142, 147, 157, 163], Selected Trial Index: 157, Video Folder Path: /media/yiting/NewVolume/Data/Videos/2025-12-07/cameras/2025-12-07_10-21-15_027548
# Shape ID: G123_0, Trials: [178, 179, 180, 181, 209, 212, 220, 225, 233, 245, 246], Selected Trial Index: 179, Video Folder Path: /media/yiting/NewVolume/Data/Videos/2025-12-07/cameras/2025-12-07_10-26-52_282850
# Shape ID: G226_2, Trials: [364, 365, 375, 378, 379, 380, 381, 414, 427, 428], Selected Trial Index: 381, Video Folder Path: /media/yiting/NewVolume/Data/Videos/2025-12-07/cameras/2025-12-07_12-07-31_570657
# Shape ID: G273_02, Trials: [511, 519, 521, 522, 537, 544, 550, 551, 552, 553, 554, 555], Selected Trial Index: 519, Video Folder Path: /media/yiting/NewVolume/Data/Videos/2025-12-07/cameras/2025-12-07_12-39-50_876607
# Shape ID: G358_2, Trials: [3, 4, 5, 6, 46, 47, 48, 61, 70, 77], Selected Trial Index: 70, Video Folder Path: /media/yiting/NewVolume/Data/Videos/2025-12-07/cameras/2025-12-07_09-56-41_275682
# Shape ID: G851_2, Trials: [589], Selected Trial Index: 589, Video Folder Path: /media/yiting/NewVolume/Data/Videos/2025-12-07/cameras/2025-12-07_13-35-05_641547

# %% [markdown]
# ## Concatenate videos during grasping window

# %%
from moviepy import VideoFileClip

cameras = ["camTo", "camTL", "camTR", "camBL", "camBR"]
trial_folders = glob(os.path.join(annotation_dir, session_name, "20*"))

for cam in cameras:
    output_dir = os.path.join(annotation_dir, session_name, f"{session_name}_concat")
    os.makedirs(output_dir, exist_ok=True)
    output_path = os.path.join(output_dir, f"{cam}.mp4")
    temp_folder = os.path.join(annotation_dir, session_name, "temp_clips", cam)
    os.makedirs(temp_folder, exist_ok=True)
    temp_files_list = []
    for i, trial_folder in enumerate(trial_folders):
        video_path = os.path.join(trial_folder, f"{cam}.mp4")
        try:
            with VideoFileClip(video_path) as clip:
                # Extract the window from 2 second to 4 seconds
                # Note: .subclipped(start_time, end_time)
                cut_clip = clip.subclipped(2, 4)

                # Define temp filename
                temp_name = os.path.join(temp_folder, f"temp_{i:04d}.mp4")
                # Write immediately to disk to free memory
                # preset='ultrafast' speeds up the cut significantly
                cut_clip.write_videofile(
                    temp_name, 
                    codec="libx264", 
                    audio_codec="aac", 
                    preset="ultrafast", 
                    logger=None  # Turn off the progress bar spam
                )
                temp_files_list.append(f"file '{os.path.abspath(temp_name)}'")
        except Exception as e:
            print(f"Error processing {video_path}: {e}")
            continue

    # Use FFmpeg 'Demuxer' for the final merge (Zero RAM usage)
    # This is much faster than MoviePy's concatenate because it copies streams
    # instead of re-encoding pixels.
    list_file_path = "ffmpeg_list.txt"   
        # Write the file list formatted for FFmpeg
    with open(list_file_path, "w") as f:
        f.write("\n".join(temp_files_list))
        
    # Run FFmpeg command line
    # -f concat: Use the concat format
    # -safe 0: Allow unsafe file paths (absolute paths)
    # -c copy: COPY the streams (no re-encoding, takes seconds)
    os.system(f"ffmpeg -hide_banner -loglevel error -f concat -safe 0 -i {list_file_path} -c copy {output_path}")

    # 5. Cleanup temporary files (Optional)
    import shutil
    shutil.rmtree(temp_folder)
    os.remove(list_file_path)

    print(f"Done! Output saved to {output_path}")
# Out:
# Done! Output saved to /home/yiting/Documents/Data/Videos/Annotations/2025-12-07/2025-12-07_concat/camTo.mp4
# Done! Output saved to /home/yiting/Documents/Data/Videos/Annotations/2025-12-07/2025-12-07_concat/camTL.mp4
# Done! Output saved to /home/yiting/Documents/Data/Videos/Annotations/2025-12-07/2025-12-07_concat/camTR.mp4
# Done! Output saved to /home/yiting/Documents/Data/Videos/Annotations/2025-12-07/2025-12-07_concat/camBL.mp4
# Done! Output saved to /home/yiting/Documents/Data/Videos/Annotations/2025-12-07/2025-12-07_concat/camBR.mp4

# %% [markdown]
# ## Create a shape-id list

# %%
# Setting
data_dir = r"/media/yiting/NewVolume/Data/Videos"
annotation_dir = r"/home/yiting/Documents/Data/Videos/Annotations"
session_dirs = glob(os.path.join(data_dir, "2025-12*"))
# sessions = ["2025-12-04", "2025-12-05"]
shape_ids_all = []
for session_dir in session_dirs:
    log_dir = os.path.join(session_dir, "trial_logs")
    log_trials = sorted(glob(os.path.join(log_dir, "*.json")))
    logs = load_log_trials(log_trials)
    shape_ids = logs["shape_id"]
    shape_ids_all.append(shape_ids)
if shape_ids_all:
    # This handles cases where sessions have different lengths (ragged arrays)
    flat_shape_ids = np.concatenate(shape_ids_all)
    unique_shape_ids = np.unique(flat_shape_ids)
else:
    unique_shape_ids = np.array([])

# %%
# Save the list of shape
save_path = os.path.join(annotation_dir, "shape_ids_2025-12.npy")
np.save(save_path, unique_shape_ids)
