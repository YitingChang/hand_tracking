# %%
from pathlib import Path
import pandas as pd
import numpy as np

# %%
SHAPE_DIR = Path("/media/yiting/NewVolume/Data/Shapes")
sym_file_path = SHAPE_DIR / "symmetry_results_img_ref-Left_ori-180.csv"
# sym_file_path = SHAPE_DIR / "symmetry_results_res-128_ori-180.csv"
sym_df = pd.read_csv(sym_file_path)
sym_df["similarity_score"].hist(bins=20)
# Out:
# <Axes: >

# %%
SHAPE_DIR = Path("/media/yiting/NewVolume/Data/Shapes")
sym_file_path = SHAPE_DIR / "symmetry_results_stl_res-64_ori-180.csv"
sym_df = pd.read_csv(sym_file_path)
sym_df["similarity_score"].hist(bins=20)
# Out:
# <Axes: >

# %%
SHAPE_DIR = Path("/media/yiting/NewVolume/Data/Shapes")
sym_file_path = SHAPE_DIR / "symmetry_results_img_ori-180.csv"
sym_df = pd.read_csv(sym_file_path)

# Average similarity across views
avg_similarity = sym_df.groupby("object_id")["similarity_score"].mean()
avg_similarity.hist(bins=20)
# Out:
# <Axes: >
